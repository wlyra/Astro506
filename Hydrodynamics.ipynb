# %% [markdown]
# # Hydrodynamics
#
# ## 1 Distribution function
#
# To describe the state of the gas statistically, we define the distribution function $f (\mathbf{x}, \mathbf{v}, t)$ such that $f d^3x d^3v$ is the average number of particles contained in a volume element $d^3x$ about $\mathbf{x}$ and a velocity-space element $d^3v$ about $\mathbf{v}$ at time $t$. Macroscopic properties of the gas can be computed from $f (\mathbf{x}, \mathbf{v}, t)$, e.g.:
#
# \begin{eqnarray}
# n(\mathbf{x}, t) &=& \int_{-\infty}^\infty f (\mathbf{x}, \mathbf{v}, t) \ d^3v \\
# \rho(\mathbf{x}, t) &=& m \ n(\mathbf{x}, t)\\
# \mathbf{u}(\mathbf{x}, t) &=& \frac{1}{n}\int_{-\infty}^\infty f (\mathbf{x}, \mathbf{v}, t) \ \mathbf{v} \ d^3v = \langle \mathbf{v} \rangle
# \end{eqnarray}
#
#
# i.e. the number density of the particles $n$, the mass density $\rho$ (where $m$ is the mass of a single particle) and the average velocity of a gas parcel $\mathbf{u}$ (= macroscopic flow velocity).
#
# We demand that $f \geq 0$ and that $f \rightarrow 0$ as the components of the particle velocity tends to infinity, sufficiently rapidly to guarantee that a finite number of particles has a finite energy.
#
# To study macroscopic properties of the gas it is useful to decompose the particle velocity $\mathbf{v}$ into the average velocity $\mathbf{u}$ and a random velocity relative to the mean flow $\mathbf{w}$
#
#
# \begin{equation}
# \mathbf{v} = \mathbf{u} + \mathbf{w}
# \end{equation}

# %% [markdown]
# ## 1.1 Boltzmann Equation
#
# We now search for an equation describing the changes of $f (\mathbf{x}, \mathbf{v}, t)$ with time. Consider a group of particles located in a phase-space volume element $(d\mathbf{x}_0, d\mathbf{v}_0)$ around ($\mathbf{x}_0, \mathbf{v}_0$). We assume that an external force $\mathbf{F}(\mathbf{x}, t)$ is acting on the particles so that they experience an acceleration $\mathbf{a}(\mathbf{x}, t) = \mathbf{F}(\mathbf{x}, t)/m$. For the moment, we ignore collisions (and interactions) between the particles. The phase-space element will evolve into ($d\mathbf{x},d\mathbf{v}$) around ($\mathbf{x},\mathbf{v}$) where
#
# \begin{eqnarray}
# \mathbf{x} &=& \mathbf{x}_0 + \mathbf{v}_0 dt \\
# \mathbf{v} &=& \mathbf{v}_0 + \mathbf{a} dt
# \end{eqnarray}
#
# Because of the Hamiltonian nature of the coordinates $\mathbf{x},\mathbf{v}$, the transformation conserves volume in phase space (Liouville's theorem)
#
# \begin{equation}
# d^3x \ d^3v = d^3x_0 \ d^3v_0
# \end{equation}
#
# The number of particles inside the original phase-space element is
#
# \begin{equation}
# dN_0 =f(\mathbf{x}_0,\mathbf{v}_0,t_0)\ d^3x_0 \ d^3v_0
# \end{equation}
#
# if the number of particles is conserved $dN_0 = dN$ where
#
# \begin{eqnarray}
# dN &=& f(\mathbf{x},\mathbf{v},t) \ d^3x \ d^3v \\
# &=& f(\mathbf{x}_0 +\mathbf{v}_0 dt,\mathbf{v}_0 +\mathbf{a}dt,t_0 +dt)\ d^3x \ d^3v
# \end{eqnarray}
#
#
# Together with Liouville's theorem, this implies that
#
# \begin{equation}
# f(\mathbf{x}_0 + \mathbf{v}_0dt,\mathbf{v}_0 +\mathbf{a}dt,t_0 + dt)=f(\mathbf{x}_0,\mathbf{v}_0,t_0)
# \end{equation}
#
#
# i.e. in the absence of collisions the phase-space density of a group of particles is <b>invariant</b>; that is
#
#
# \begin{equation}
# \frac{Df}{Dt} = 0
# \end{equation}
#
#
# Expanding the material derivative
#
# \begin{equation}
# \boxed{
# \frac{\partial f}{\partial t} + \mathbf{\dot{x}}\cdot\nabla_x f + \mathbf{\dot{v}}\cdot\nabla_v f = 0
# }
# \end{equation}
#
# which is known as the <b>collisionless Boltzmann's equation</b>, or <b>Vlasov’s equation</b>.
#
# It is useful to write it in component form
#
# \begin{equation}
# \frac{\partial f}{\partial t} + \dot{x}_i\frac{\partial}{\partial x_i}f + \dot{v}_i\frac{\partial}{\partial v_i} f = 0
# \end{equation}
#
# Notice that the equation can be written as
#
# \begin{equation}
# \frac{\partial f}{\partial t} + \nabla_{6D}\cdot \left( f \mathbf{W} \right) = 0
# \end{equation}
#
# where $\mathbf{W} = (\mathbf{x},\mathbf{v})$ is a 6D state vector and $\nabla_{6D}$ is a 6D divergence. This equation has the form of the continuity equation. Boltzmann's equation is derived under the condition that no particle can jump in phase space. Particles can only go smoothly (continuously) from one place to another. Thus, the Boltzmann equation is just the continuity equation of the flow of particles in phase space.

# %% [markdown]
# ## 1.2 Moments of the Boltzmann Equation
#
# The equations of fluid dynamics can be derived by calculating moments of the Boltzmann equation for quantities that are conserved.
#
# ### 1.2.1 The Conservation Theorem
#
# We form moments of the Boltzmann equation by multiplying by a quantity $Q$ and integrating
#
# \begin{equation}
# \int Q \left( \frac{\partial f}{\partial t} + \mathbf{v}\cdot\nabla_x f + \mathbf{a}\cdot\nabla_v f \right) d^3 v  = 0
# \end{equation}
#
# In the following discussion we assume that $Q$ is conserved. The moment equation then can be transformed into the conservation theorem. For that, we split the equation above into three integrals. Call this Eq (1)
#
# \begin{equation}
# \int Q \frac{\partial f}{\partial t}d^3 v  + \int Q\mathbf{v}\cdot\nabla_x f  d^3v + \int Q \mathbf{a}\cdot\nabla_v f d^3 v  = 0  \quad\quad\quad (\mathrm{1})
# \end{equation}
#
# We treat each term separately. For the first integral
#
# \begin{equation}
# \frac{\partial }{\partial t}  \int Q f d^3 v  =  \int Q \frac{\partial f}{\partial t} d^3 v + \int f \frac{\partial Q}{\partial t} d^3 v
# \end{equation}
#
# Isolating the term containing $\partial_t f$
#
# \begin{equation}
# \int Q \frac{\partial f}{\partial t} d^3 v  = \frac{\partial }{\partial t}  \int Q f d^3 v  - \int f \frac{\partial Q}{\partial t} d^3 v  \quad\quad\quad (\mathrm{2})
# \end{equation}
#
# For the second integral
#
# \begin{equation}
# \frac{\partial}{\partial x_i}\int Q v_i f  d^3v  = \int \frac{\partial Q}{\partial x_i} v_i f  d^3v + \int Q \frac{\partial v_i}{\partial x_i} f  d^3v + \int Q v_i \frac{\partial f}{\partial x_i}  d^3v
# \end{equation}
#
# and because $v$ and $x$ are independent, the middle integral vanishes, leading to
#
#
# \begin{equation}
# \int Q v_i \frac{\partial f}{\partial x_i}  d^3v =  \frac{\partial}{\partial x_i}\int Q v_i f  d^3v   -\int \frac{\partial Q}{\partial x_i} v_i f  d^3v  \quad\quad\quad (\mathrm{3})
# \end{equation}
#
# As for the 3rd integral, along the same lines
#
# \begin{equation}
# \frac{\partial}{\partial v_i}\int Q a_i f  d^3v  = \int \frac{\partial Q}{\partial v_i} a_i f  d^3v + \int Q \frac{\partial a_i}{\partial v_i} f  d^3v + \int Q a_i \frac{\partial f}{\partial v_i}  d^3v
# \end{equation}
#
# Isolating the last integral
#
# \begin{equation}
# \int Q a_i \frac{\partial f}{\partial v_i}  d^3v   = \frac{\partial}{\partial v_i}\int Q a_i f  d^3v  - \int \frac{\partial Q}{\partial v_i} a_i f  d^3v - \int Q \frac{\partial a_i}{\partial v_i} f  d^3v  \quad\quad\quad (\mathrm{4})
# \end{equation}
#
#
# Substituting Eqs (2), (3), and (4) into Eq (1)
#
#
# \begin{equation}
# \frac{\partial }{\partial t}  \int Q f d^3 v   - \int f \frac{\partial Q}{\partial t} d^3 v +  \frac{\partial}{\partial x_i}\int Q v_i f  d^3v   -\int \frac{\partial Q}{\partial x_i} v_i f  d^3v + \frac{\partial}{\partial v_i}\int Q a_i f  d^3v  - \int \frac{\partial Q}{\partial v_i} a_i f  d^3v - \int Q \frac{\partial a_i}{\partial v_i} f  d^3v = 0  \quad\quad\quad (\mathrm{5})
# \end{equation}
#
# #### Simplification
#
#
# The fifth term in Eq (5) cancels because it is the divergence of a volume integral. By virtue of Gauss theorem we replace by an area integral, and make the radius infinite, where $f$ vanishes.
#
# \begin{equation}
# \frac{\partial }{\partial t}  \int Q f d^3 v   - \int f \frac{\partial Q}{\partial t} d^3 v +  \frac{\partial}{\partial x_i}\int Q v_i f  d^3v   -\int \frac{\partial Q}{\partial x_i} v_i f  d^3v - \int \frac{\partial Q}{\partial v_i} a_i f  d^3v - \int Q \frac{\partial a_i}{\partial v_i} f  d^3v = 0
# \end{equation}
#
#
# Considering that the acceleration is independent of the velocity, we eliminate the last term
#
#
# \begin{equation}
# \frac{\partial }{\partial t}  \int Q f d^3 v   - \int f \frac{\partial Q}{\partial t} d^3 v +  \frac{\partial}{\partial x_i}\int Q v_i f  d^3v   -\int \frac{\partial Q}{\partial x_i} v_i f  d^3v - \int \frac{\partial Q}{\partial v_i} a_i f  d^3v = 0
# \end{equation}
#
# And because the quantity $Q$ is conserved, i.e.,
#
# \begin{equation}
# \frac{D Q}{D t}  = \frac{\partial Q}{\partial t}  + v_i\frac{\partial Q}{\partial x_i} = 0
# \end{equation}
#
# the 2nd and 4th term cancel together. This finally leaves
#
# \begin{equation}
# \frac{\partial }{\partial t}  \int Q f d^3 v   +  \frac{\partial}{\partial x_i}\int Q v_i f  d^3v   - \int \frac{\partial Q}{\partial v_i} a_i f  d^3v = 0 \quad\quad\quad (\mathrm{6})
# \end{equation}
#
# #### Averaging
#
#
# The average value $\langle A \rangle$ of a quantity $A$ is
#
# \begin{equation}
# \langle A \rangle = \frac{\int A f d^3v}{\int f d^3v} = \frac{1}{n}\int A f d^3v
# \end{equation}
#
# That is
#
# \begin{equation}
# \int A f d^3v = n \langle A \rangle
# \end{equation}
#
# Using this definition, Eq (6) becomes the equation below, the <b>conservation theorem</b>
#
# \begin{equation}
# \boxed{
# \frac{\partial }{\partial t} \left(n\langle Q \rangle\right) + \nabla_x \cdot \left(n\langle Q  \mathbf{v} \rangle\right) - n\mathbf{a}\cdot \langle \nabla_v Q \rangle = 0
# }
# \end{equation}
#
# For a gas consisting of particles which have no inner structure we have 5 conserved
# quantities $Q$, these are the mass $m$, the three components of the momentum $m\mathbf{v}$, and the energy $mv^2/2$.

# %% [markdown]
# ## The equations of Hydrodynamics
#
# ### Mass conservation: The Equation of Continuity
#
# If we choose $Q = m$ and insert this into the conservation equation, we get
#
# \begin{equation}
# \frac{\partial }{\partial t} \left(n m\right) + \nabla_x \cdot \left(nm\langle \mathbf{v} \rangle \right)  = 0
# \end{equation}
#
# Using $nm=\rho$ and $\mathbf{u} = \langle \mathbf{v} \rangle$ we obtain the <b>continuity equation</b>
#
# \begin{equation}
# \boxed{
# \frac{\partial \rho}{\partial t}  + \nabla \cdot \left(\rho \mathbf{u} \right)  = 0
# }
# \end{equation}
#
# Notice that we can use the product rule in the gradient and write the continuity equation as
#
# \begin{equation}
# \frac{\partial \rho}{\partial t}  + \left(\mathbf{u} \cdot \nabla\right) \rho = - \rho \nabla \cdot  \mathbf{u}
# \end{equation}
#
#
# In this form, we recognize the second term as an <i>advection</i> term. This term transports the density along a streamline. The last terms depends on the divergence of the velocity, and is the <i>compression</i> term. A negative divergence (convergence) increases the density. A positive divergence decreases it.
#
# ### Momentum conservation: The Navier-Stokes Equation
#
# If $Q = mv_i$ (the i-th component of the particle momentum), the conservation equation becomes
#
#
# \begin{equation}
# \frac{\partial }{\partial t} \left(nm\langle v_i \rangle\right) + \frac{\partial}{\partial x_j} \left(nm\langle v_i  v_j \rangle\right) - nm a_j \left\langle \frac{\partial}{\partial v_j} v_i \right\rangle = 0
# \end{equation}
#
# substitute $nm$ by the density
#
#
# \begin{equation}
# \frac{\partial }{\partial t} \left(\rho\langle v_i \rangle\right) + \frac{\partial}{\partial x_j} \left(\rho\langle v_i  v_j \rangle\right) - \rho a_j \left\langle \frac{\partial}{\partial v_j} v_i \right\rangle = 0
# \end{equation}
#
# In the last term the derivative is a Kronecker delta.
#
#
# \begin{equation}
# \frac{\partial }{\partial t} \left(\rho\langle v_i \rangle\right) + \frac{\partial}{\partial x_j} \left(\rho\langle v_i  v_j \rangle\right) - \rho a_j \delta_{ij} = 0
# \end{equation}
#
# leaving only $a_i$
#
#
# \begin{equation}
# \frac{\partial }{\partial t} \left(\rho\langle v_i \rangle\right) + \frac{\partial}{\partial x_j} \left(\rho\langle v_i  v_j \rangle\right) = \rho a_i
# \end{equation}
#
# Substituting $\langle v_i \rangle \equiv u_i$ for the mean flow velocity
#
# \begin{equation}
# \frac{\partial }{\partial t} \left(\rho u_i \right) + \frac{\partial}{\partial x_j} \left(\rho\langle v_i  v_j \rangle\right) = \rho a_i
# \end{equation}
#
# Keeping in mind that we are using the decomposition $v_i = u_i + w_i$ (particle velocity = mean flow velocity + random component) where $\langle w_i \rangle = 0$.
#
#
# We can define the tensor
#
# \begin{equation}
# P_{ij} = \rho \langle w_i w_j\rangle
# \end{equation}
#
# and substituting $w_i = v_i - u_i$
#
# \begin{eqnarray}
# P_{ij} &=& \rho \langle (v_i - u_i)(v_j - u_j)\rangle\\
# &=&\rho \langle v_iv_j - v_i u_j - u_iv_j + u_iu_j\rangle\\
# &=&\rho \left(\langle v_iv_j\rangle - \langle v_i \rangle u_j - u_i\langle v_j\rangle + u_iu_j\right)\\
# &=&\rho \left(\langle v_iv_j\rangle - u_iu_j\right)
# \end{eqnarray}
#
# We thus have an expression for $\rho\langle v_i  v_j \rangle$
#
#
# \begin{equation}
# \rho \langle v_iv_j\rangle = \rho u_iu_j + P_{ij}
# \end{equation}
#
#
# Substituting this expression, we find the momentum-conservation equation
#
# \begin{equation}
# \boxed{
# \frac{\partial }{\partial t} \left(\rho u_i \right) + \frac{\partial}{\partial x_j} \left(\rho\langle u_i  u_j \rangle\right) = -\frac{\partial P_{ij}}{\partial x_j}  + \rho a_i
# }
# \end{equation}
#
#
# We can cast the equation in an advection form by expanding the first term
#
#
# \begin{equation}
# \rho \frac{\partial u_i}{\partial t} + u_i \frac{\partial \rho}{\partial t} +  + \frac{\partial}{\partial x_j} \left(\rho u_i  u_j \right) = -\frac{\partial P_{ij}}{\partial x_j}  + \rho a_i
# \end{equation}
#
# and using the mass continuity equation to remove $\frac{\partial \rho}{\partial t}$
#
#
# \begin{equation}
# \rho \frac{\partial u_i}{\partial t} - u_i \frac{\partial}{\partial x_j} \left(\rho u_j\right)  + \frac{\partial}{\partial x_j} \left(\rho u_i  u_j \right) = -\frac{\partial P_{ij}}{\partial x_j}  + \rho a_i
# \end{equation}
#
# expanding the 3rd term cancels the 2nd term, leaving
#
# \begin{equation}
# \rho \frac{\partial u_i}{\partial t}  + \rho  u_j\frac{\partial}{\partial x_j}u_i = -\frac{\partial P_{ij}}{\partial x_j}  + \rho a_i
# \end{equation}
#
#
# Diving all terms by $\rho$
#
#
# \begin{equation}
# \frac{\partial u_i}{\partial t}  +  u_j\frac{\partial}{\partial x_j}u_i = -\frac{1}{\rho}\frac{\partial P_{ij}}{\partial x_j}  + a_i
# \end{equation}
#
# We can decompose the tensor $P$ into a diagonal term, $p$, the pressure, and a traceless component
#
# \begin{equation}
# P_{ij} \equiv p \delta_{ij} - \Pi_{ij}
# \end{equation}
#
# Given how we defined $P_{ij}$, the pressure is
#
# \begin{equation}
# p =  \frac{1}{3} \rho \langle w^2 \rangle
# \end{equation}
#
# And the tensor $\Pi_{ij}$ is found by
#
# \begin{eqnarray}
# \Pi_{ij} &=& p \delta_{ij} - P_{ij}  \\
# &=&\rho\left(\frac{1}{3}\langle w^2 \rangle - \langle w_i w_j \rangle \right)
# \end{eqnarray}
#
# this tensor is the viscous stress tensor.
#
# The Navier Stokes equation then becomes
#
#
# \begin{equation}
# \frac{\partial \mathbf{u}}{\partial t}  +  \left(\mathbf{u}\cdot \nabla\right) \mathbf{u} = -\frac{1}{\rho} \nabla p  + \mathbf{a} +\frac{1}{\rho}\nabla\cdot\Pi
# \end{equation}

# %% [markdown]
# ##### The Energy Equation
#
# Going back to the conservation equation
#
# \begin{equation}
# \frac{\partial }{\partial t} \left(n\langle Q \rangle\right) + \nabla_x \cdot \left(n\langle Q  \mathbf{v} \rangle\right) - n\mathbf{a}\cdot \langle \nabla_v Q \rangle = 0
# \end{equation}
#
#
# If we choose $Q = mv^2/2$, the conservation equation assumes the form
#
#
# \begin{equation}
# \frac{\partial }{\partial t} \left(\frac{1}{2}n m \langle v^2 \rangle\right) + \frac{\partial}{\partial x_j}\left(\frac{1}{2}nm\langle v^2v_j \rangle\right) - \frac{1}{2}nma_j \left\langle \frac{\partial}{\partial v_j} v^2 \right\rangle = 0
# \end{equation}
#
# We write this as $A+B+C=0$ and work out the individual terms. The first term is
#
# \begin{eqnarray}
# A &=& \frac{\partial }{\partial t} \left(\frac{1}{2}\rho \langle v^2 \rangle\right)\\
# &=& \frac{\partial }{\partial t} \left[\frac{1}{2}\rho \left(u^2 + 2u\langle w \rangle + \langle w^2 \rangle\right)\right]
# \end{eqnarray}
#
# Given that $\langle w \rangle = 0$, the middle term cancels, and we have
#
# \begin{equation}
# A = \frac{\partial }{\partial t} \left(\frac{1}{2}\rho u^2 + \rho e \right)
# \end{equation}
#
# where we define the <b>specific internal energy</b>
#
# \begin{equation}
# e \equiv \frac{1}{2} \langle w^2\rangle
# \end{equation}
#
# and the total energy (bulk kinetic plus thermal) is
#
# \begin{equation}
# E \equiv \frac{u^2}{2} + e
# \end{equation}
#
# The second term is
#
# \begin{equation}
# B = \frac{\partial}{\partial x_j}\left(\frac{1}{2}nm\langle v^2v_j \rangle\right)
# \end{equation}
#
# Again expanding $\mathbf{v} = \mathbf{u} + \mathbf{w}$, this becomes
#
# \begin{equation}
# B = \frac{\partial}{\partial x_j}\left[\frac{1}{2}\rho\langle (u^2 + 2u_iw_i + w^2)(u_j + w_j) \rangle\right]
# \end{equation}
#
#
# Expanding the brackets,
#
# \begin{equation}
# B = \frac{\partial}{\partial x_j}\left\{ \frac{\rho}{2}\left[(u^2 + 2u_i\langle w_i\rangle + \langle w^2\rangle)u_j + u^2\langle w_j\rangle + 2u_i\langle w_i w_j\rangle + \langle w^2 w_j \rangle \right]\right\}
# \end{equation}
#
# and because $\langle w_i \rangle = 0$, the second term in the first parentheses cancels, as well as the first term after the parentheses, leading to
#
# \begin{equation}
# B = \frac{\partial}{\partial x_j}\left\{ \frac{\rho}{2}\left[(u^2 + \langle w^2\rangle)u_j + 2u_i\langle w_i w_j\rangle + \langle w^2 w_j \rangle \right]\right\}
# \end{equation}
#
# We now substitute $\langle w^2\rangle$ by the internal energy, and $\langle w_i w_j\rangle$ by the stress tensor $P_{ij}$.
#
#
# \begin{equation}
# B = \frac{\partial}{\partial x_j}\left\{ \left[\left(\frac{\rho}{2}u^2 + \rho e\right)u_j + u_iP_{ij}  + \frac{1}{2}\rho \langle w^2 w_j \rangle \right]\right\}
# \end{equation}
#
#
# The last term is defined as the <b>heat conduction flow</b>
#
# \begin{equation}
# \mathbf{H} \equiv  \frac{\rho}{2} \langle w^2 \mathbf{w} \rangle
# \end{equation}
#
# So
#
# \begin{equation}
# B = \frac{\partial}{\partial x_j}\left\{ \left[\left(\frac{\rho}{2}u^2 + \rho e\right)u_j + u_iP_{ij}  + H_j \right]\right\}
# \end{equation}
#
# The last term is
#
#
# \begin{eqnarray}
# C &=&\frac{1}{2}nma_j \left\langle \frac{\partial}{\partial v_j} v^2 \right\rangle \\
# &=&\frac{1}{2}\rho a_j \left\langle \frac{\partial}{\partial v_j} v_k v_k \right\rangle \\
# &=&\rho a_j \left\langle v_k \delta_{jk}\right\rangle \\
# &=&\rho a_j \left\langle v_j\right\rangle \\
# &=&\rho a_j \left\langle u_j  + w_j \right\rangle \\
# &=&\rho a_j u_j \\
# \end{eqnarray}
#
# Thus, collecting all terms
#
# \begin{equation}
# \frac{\partial }{\partial t} \left(\frac{1}{2}\rho u^2 + \rho e \right) + \frac{\partial}{\partial x_j}\left[ \left(\frac{1}{2}\rho u^2 + \rho e \right)u_j + P_{ij}u_i + H_j\right] = \rho a_j u_j
# \end{equation}
#
# Substituting $E$ for the energy
#
# \begin{equation}
# \frac{\partial E}{\partial t} + \frac{\partial}{\partial x_j}\left[ E u_j + P_{ij}u_i + H_j\right] = \rho a_j u_j
# \end{equation}
#
# or, in vector notation
#
# \begin{equation}
# \frac{\partial E}{\partial t} + \nabla \cdot \left( E \mathbf{u} + \mathbf{P}\cdot\mathbf{u} + \mathbf{H}\right) = \rho \ \mathbf{a}\cdot\mathbf{u}
# \end{equation}
#
# substituting the viscous tensor
#
# \begin{equation}
# \boxed{
# \frac{\partial E}{\partial t} + \nabla \cdot \left[ (E+p) \mathbf{u} \right] = \rho \ \mathbf{a}\cdot\mathbf{u}  - \nabla\cdot \mathbf{H} + \nabla \cdot \left(\mathbf{\Pi}\cdot\mathbf{u}\right)
# }
# \end{equation}
#
#
#
#
# These conservation equations are exact for the adopted model of the gas but have no practical value until we can evaluate the viscous tensor and the heat conduction flow. Using kinetic theory this can be done from first principles.

# %% [markdown]
# ##### Conservation Equations for Equilibrium Flow
#
# The gas can be considered to be in local equilibrium if particle mean free paths are very small compared to characteristic length scales of the flow and if gradients are sufficiently small. Then we can assume that the distribution function $f(\mathbf{x},\mathbf{v},t)$ is given by a Maxwellian velocity distribution
#
# \begin{equation}
# f(w) =  n \left(\frac{m}{2\pi k T}\right)^{3/2} \mathrm{exp}\left(-\frac{mw^2}{2kT}\right)
# \end{equation}
#
# with a local temperature $T$ and particle density $n$ ($w$ is the random part of the particle velocity as before).
#
# Using this distribution function it can be shown that $\Pi_{ij}$ and $H_i$ as defined in the previous section are <b>zero</b>. Therefore, the conservation equations become
#
# \begin{eqnarray}
# \frac{\partial \rho}{\partial t}  + \left(\mathbf{u}\cdot \nabla\right)\rho  &=& -\rho \nabla \cdot \mathbf{u}   \\
# \frac{\partial \mathbf{u}}{\partial t}  +  \left(\mathbf{u}\cdot \nabla\right) \mathbf{u} &=& -\frac{1}{\rho} \nabla p  + \mathbf{a} \\
# \frac{\partial E}{\partial t} + \nabla \cdot \left[ (E+p) \mathbf{u} \right] &=& \rho \ \mathbf{a}\cdot\mathbf{u}
# \end{eqnarray}

# %% [markdown]
# ### Acoustics
#
# Let us consider the isothermal hydro equations, in the absence of body forces
#
# \begin{eqnarray}
# \frac{\partial \rho}{\partial t}  + \left(\mathbf{u}\cdot \nabla\right)\rho  &=& -\rho \nabla \cdot \mathbf{u}   \\
# \frac{\partial \mathbf{u}}{\partial t}  +  \left(\mathbf{u}\cdot \nabla\right) \mathbf{u} &=& -\frac{1}{\rho} \nabla p
# \end{eqnarray}
#
# and closed with the equation of state for ideal gases
#
# \begin{equation}
# p = \rho c_s^2/\gamma
# \end{equation}
#
# with $\gamma=1$ for isothermal and $c_s$ is the sound speed
#
# And consider a one-dimensional configuration, so that $\mathbf{u}=u$
#
# \begin{eqnarray}
# \frac{\partial \rho}{\partial t}  + u\frac{\partial \rho}{\partial x} &=& -\rho\frac{\partial u}{\partial x}    \\
# \frac{\partial u}{\partial t}  +  u\frac{\partial u}{\partial x} &=& -\frac{1}{\rho} \frac{\partial p}{\partial x}  \\
# \end{eqnarray}
#
# This system admits waves. To find the waves, let us linearize the system, decomposing it into base and perturbation, ie any quantity $Q$ is decomposed into a base state $\bar{Q}$ and a perturbation $Q^\prime$
#
# \begin{equation}
# Q = \bar{Q} + Q^\prime
# \end{equation}
#
# This way, the equations are expressed as
#
#
# \begin{eqnarray}
# \frac{\partial (\bar{\rho}+\rho^\prime)}{\partial t}  + (\bar{u}+u^\prime)\frac{\partial (\bar{\rho}+\rho^\prime)}{\partial x} &=& -(\bar{\rho}+\rho^\prime)\frac{\partial (\bar{u}+u^\prime)}{\partial x}   \\
# \frac{\partial (\bar{u}+u^\prime)}{\partial t}  +  (\bar{u}+u^\prime)\frac{\partial (\bar{u}+u^\prime)}{\partial x} &=& -\frac{1}{(\bar{\rho}+\rho^\prime)} \frac{\partial (\bar{p}+p^\prime)}{\partial x}
# \end{eqnarray}
#
# consider now that the base state is constant, so its derivatives (in time and space) cancel
#
#
# \begin{eqnarray}
# \frac{\partial \rho^\prime}{\partial t}  + (\bar{u}+u^\prime)\frac{\partial \rho^\prime}{\partial x} &=& -(\bar{\rho}+\rho^\prime)\frac{\partial u^\prime}{\partial x}   \\
# \frac{\partial u^\prime}{\partial t}  +  (\bar{u}+u^\prime)\frac{\partial u^\prime}{\partial x} &=& -\frac{1}{(\bar{\rho}+\rho^\prime)} \frac{\partial p^\prime}{\partial x}
# \end{eqnarray}
#
# consider also that the system is Galilean-invariant, so we can set $\bar{u}=0$
#
# \begin{eqnarray}
# \frac{\partial \rho^\prime}{\partial t}  + u^\prime\frac{\partial \rho^\prime}{\partial x} &=& -(\bar{\rho}+\rho^\prime)\frac{\partial u^\prime}{\partial x}   \\
# \frac{\partial u^\prime}{\partial t}  +  u^\prime\frac{\partial u^\prime}{\partial x} &=& -\frac{1}{(\bar{\rho}+\rho^\prime)} \frac{\partial p^\prime}{\partial x}
# \end{eqnarray}
#
# and that the base state of density is much larger than its pertubation $\bar{\rho}\gg \rho^\prime$.
#
# \begin{eqnarray}
# \frac{\partial \rho^\prime}{\partial t}  + u^\prime\frac{\partial \rho^\prime}{\partial x} &=& -\bar{\rho}\frac{\partial u^\prime}{\partial x}   \\
# \frac{\partial u^\prime}{\partial t}  +  u^\prime\frac{\partial u^\prime}{\partial x} &=& -\frac{1}{\bar{\rho}} \frac{\partial p^\prime}{\partial x}
# \end{eqnarray}
#
# Two primed quantities are of second order, and ignored, canceling the nonlinear term. We have thus a simple system
#
# \begin{eqnarray}
# \frac{\partial \rho^\prime}{\partial t}   &=& -\bar{\rho}\frac{\partial u^\prime}{\partial x}   \\
# \frac{\partial u^\prime}{\partial t}   &=& -\frac{1}{\bar{\rho}} \frac{\partial p^\prime}{\partial x}
# \end{eqnarray}
#
# ### Wave solution
#
# We take the time derivative of both equations
#
#
# \begin{eqnarray}
# \frac{\partial^2 \rho^\prime}{\partial t^2}   &=& -\bar{\rho}\frac{\partial }{\partial x} \frac{\partial u^\prime}{\partial t}  \\
# \frac{\partial^2 u^\prime}{\partial t^2}   &=& -\frac{1}{\bar{\rho}} \frac{\partial }{\partial x} \frac{\partial p^\prime}{\partial t}
# \end{eqnarray}
#
# and substituting the equation for the time derivative of $u^\prime$
#
# \begin{eqnarray}
# \frac{\partial^2 \rho^\prime}{\partial t^2}   &=& \frac{\partial^2 p^\prime}{\partial x^2} \\
# \frac{\partial^2 u^\prime}{\partial t^2}   &=& -\frac{1}{\bar{\rho}} \frac{\partial }{\partial x} \frac{\partial p^\prime}{\partial t}
# \end{eqnarray}
#
#
# To progress, we need an equation of state. We will use the ideal gas law, which leads to
#
# \begin{eqnarray}
# \frac{\partial^2 \rho^\prime}{\partial t^2}   &=& c_s^2 \frac{\partial^2 \rho^\prime}{\partial x^2} \\
# \frac{\partial^2 u^\prime}{\partial t^2}   &=& -\frac{c_s^2}{\bar{\rho}} \frac{\partial }{\partial x} \frac{\partial \rho^\prime}{\partial t}
# \end{eqnarray}
#
# substituting the equation for the time derivative of $\rho^\prime$
#
# \begin{eqnarray}
# \frac{\partial^2 \rho^\prime}{\partial t^2}   &=& c_s^2 \frac{\partial^2 \rho^\prime}{\partial x^2} \\
# \frac{\partial^2 u^\prime}{\partial t^2}   &=& c_s^2 \frac{\partial^2 u^\prime}{\partial x^2}
# \end{eqnarray}
#
# These are <i>wave equations</i>, that describe a sound wave. The speed of the wave is the sound speed $c_s$. The wave propagates in the same direction of travel, being longitudinal.
#
# ### Dispersion relation
#
# Another way to derive the wave solution is by finding the <i>dispersion relation</i>, which is the relation between frequency and wavelength. Considering again the original equations
#
# \begin{eqnarray}
# \frac{\partial \rho^\prime}{\partial t}   &=& -\bar{\rho}\frac{\partial u^\prime}{\partial x}   \\
# \frac{\partial u^\prime}{\partial t}   &=& -\frac{1}{\bar{\rho}} \frac{\partial p^\prime}{\partial x}
# \end{eqnarray}
#
# Let us decompose the fields $\rho$ and $u$ into Fourier modes $\psi = \hat{\psi} \mbox{exp}[-i(\omega t + kx)]$
#
# \begin{eqnarray}
# -i\omega\hat{\rho} &=& \bar{\rho} i k \hat{u} \\
# -i\omega\hat{u}  &=& \frac{c_s^2}{\bar{\rho}}ik\hat{\rho}
# \end{eqnarray}
#
# Isolating $\hat{u}$ in the second equation and substituting it on the first
#
# \begin{equation}
# \omega^2= k^2 c_s^2
# \end{equation}
#
# so $\omega = \pm k c_s$. Plugging it back in the Fourier mode
#
# \begin{equation}
# \psi = \hat{\psi} \mbox{exp}[-i k ( x + c_s t)]
# \end{equation}
#
# The system is Galilean invariant over the transformation $x \longrightarrow x \pm c_s t$, so this is a wave, propagating with velocity $c_s$, the sound speed.

# %% [markdown]
# ### References
#
# A.R. Choudhuri, The Physics of Fluids and Plasmas, An Introduction for Astrophysicists, Cambridge University Press, 1998, chapters 1-3
#
# F.H. Shu, The Physics of Astrophysics, Vol.II: Gas Dynamics, University Science Books, 1992, p. 14-28
#
# S. Hofner, The equations of fluid dynamics and their connection with the Boltzmann equation
# Lecture Notes; Department of Physics and Astronomy Uppsala University

# %%
nu = 1.5e-5 #m^2/s
U = 300 #m/s
L = 1e3 #m 

Re = L*U/nu 

print(Re/1e9)
# Out:
# 20.0

# %%
nu = 1e7 #cm^2/s
U = 1e5 
L = 3e18

Re = L*U/nu

print(Re)
# Out:
# 3e+16

# %%
# water 
nu = 1e4 #cm^2/s
L = 0.15
U = 13.3/3600 #cm/h

Re = L*U/nu
print(Re)
# Out:
# 5.541666666666667e-08
